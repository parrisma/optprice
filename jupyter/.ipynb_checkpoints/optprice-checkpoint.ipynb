# %%
import tensorflow as tf
import numpy as np
from scipy.stats import norm
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
"""
:param S: Spot
:param K: Stike
:param T: Time to maturity
:param r: risk free rate
:param v: underlying volatility
:param o: type, call or put
"""
def black_scholes_model(S, K, T, r, v, o='c'):
    d1 = (math.log(S / K) + (r + 0.5 * v ** 2) * T) / (v * math.sqrt(T))
    d2 = (math.log(S / K) + (r - 0.5 * v ** 2) * T) / (v * math.sqrt(T))
    
    if o == 'c':
        return S * norm.cdf(d1) - K * np.exp(-r * T) * norm.cdf(d2)
    if o == 'p':
        return K * np.exp(-r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)

# %%
"""
:param resolution: how fine to break up the intervals
"""
def price_scenario(resolution, volOffset = 0.1, matOffset = (30/365), debug=True):
   nsteps = 50
   vols = [volOffset + 1e-6 + (x * (0.01 / resolution)) for x in range(0, (nsteps * resolution))]
   mats = [matOffset + 1e-6+(x * (.5/(nsteps * 2))/resolution  ) for x in range(0, (nsteps * resolution))]
   if debug:
       print("Volatilities %")
       print([ "{:0.4f}".format(v) for v in vols ])
       print("\nMaturities (fractrion of a year)")
       print([ "{:0.4f}".format(t) for t in mats ])
   return vols, mats

# %%
"""
:param vols: volatilities as %
:param mats: maturities as fraction of year
"""
def option_scenario(vols, mats, debug=True):
    prices = np.zeros((len(vols),len(mats)))
    for vi, v in enumerate(vols):
       for ti, t in enumerate(mats):
          prices[vi, ti] = black_scholes_model(S=100,K=99,T=t,r=0.05,v=v)
          if debug:
              print("{}-{} [v:{:0.3f}]-[t:{:0.3f}] = [price:{:0.3f}]".format(vi, ti, v, t, prices[vi, ti]))
    return prices

# %%
"""
:param vols: volatilities as %
:param mats: maturities as fraction of year
"""
def option_scenario_model(vols, mats, debug=True):
    X = np.zeros([(len(vols)*len(mats)),2])
    Y = np.zeros([(len(vols)*len(mats))])
    i = 0
    for vi, v in enumerate(vols):
       for ti, t in enumerate(mats):
          X[i, 0] = v
          X[i, 1] = t
          Y[i] = black_scholes_model(S=100,K=99,T=X[i, 1],r=0.05,v=X[i, 0])
          if debug:
              print("{}-{} [v:{:0.3f}]-[t:{:0.3f}] = [price:{:0.3f}]".format(vi, ti, X[i, 0], X[i, 1], Y[i]))
          i = i +1
    return X, Y

# %%
vols, mats = price_scenario(resolution=10, debug=False)
# Out:
# 500

# %%
X, Y = option_scenario_model(vols, mats, debug=False)
print(np.shape(X))
print(np.shape(Y))
# Out:
# (250000, 2)
# (250000,)

# %%
model = Sequential()
model.add(Dense(256, input_shape=(2,), kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.05))
model.add(Dense(128, kernel_initializer='normal', activation='relu'))
model.add(Dense(128, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.025))
model.add(Dense(32, kernel_initializer='normal', activation='relu'))
model.add(Dense(16, kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
import random
shuffle_idx = random.sample(range(0,len(Y)), len(Y))

# %%
Ys = Y[shuffle_idx]
Xs = X[shuffle_idx]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(Xs, Ys, test_size=0.33)

# %%
history = model.fit(X_train, y_train,
                    batch_size=16,
                    epochs=5,
                    verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 10469/10469 [==============================] - 19s 2ms/step - loss: 0.0056 - val_loss: 0.0195
# Epoch 2/5
# 10469/10469 [==============================] - 19s 2ms/step - loss: 0.0054 - val_loss: 0.0130
# Epoch 3/5
# 10469/10469 [==============================] - 20s 2ms/step - loss: 0.0052 - val_loss: 0.0111
# Epoch 4/5
# 10469/10469 [==============================] - 19s 2ms/step - loss: 0.0050 - val_loss: 0.0170
# Epoch 5/5
# 10469/10469 [==============================] - 19s 2ms/step - loss: 0.0048 - val_loss: 0.0167

# %%
skip = 1
plt.plot(history.history['loss'][skip:])
plt.plot(history.history['val_loss'][skip:])
plt.show()

# %%
vols, mats = price_scenario(resolution=1)
prices = option_scenario(vols, mats)
# Out:
# Volatilities %
# ['0.1000', '0.1100', '0.1200', '0.1300', '0.1400', '0.1500', '0.1600', '0.1700', '0.1800', '0.1900', '0.2000', '0.2100', '0.2200', '0.2300', '0.2400', '0.2500', '0.2600', '0.2700', '0.2800', '0.2900', '0.3000', '0.3100', '0.3200', '0.3300', '0.3400', '0.3500', '0.3600', '0.3700', '0.3800', '0.3900', '0.4000', '0.4100', '0.4200', '0.4300', '0.4400', '0.4500', '0.4600', '0.4700', '0.4800', '0.4900', '0.5000', '0.5100', '0.5200', '0.5300', '0.5400', '0.5500', '0.5600', '0.5700', '0.5800', '0.5900']
#
# Maturities (fractrion of a year)
# ...

# %%
def plot_price_surface(vols, mats, prices):
    X,Y = np.meshgrid(vols,mats)
    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, prices)
    ax.set_xlabel("Volatility")
    ax.set_ylabel("Maturity")
    ax.set_zlabel("Option Price")
    ax.set_title("Call Option")
    plt.show()

# %%
plot_price_surface(vols,mats,prices)

# %%
pred_prices = np.zeros((len(vols),len(mats)))
vi = 0
mi = 0
for v in vols:
   for t in mats:
      pred_prices[vi, mi] = model.predict(np.column_stack((vols[vi],mats[mi])))
      mi = mi + 1
   mi = 0
   vi = vi + 1
# Out:
# ...
# 1/1 [==============================] - 0s 17ms/step
# C:\Users\parri\AppData\Local\Temp\ipykernel_29644\1644242129.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   pred_prices[vi, mi] = model.predict(np.column_stack((vols[vi],mats[mi])))
# ...
# 1/1 [==============================] - 0s 19ms/step
# ...
# ...
# 1/1 [==============================] - 0s 16ms/step

# %%
plot_price_surface(vols,mats,pred_prices)

# %%
plt.scatter(prices.flatten(),pred_prices.flatten(),s=0.25)

# %%
plt.hist(vols)

# %%
plt.hist(mats)
